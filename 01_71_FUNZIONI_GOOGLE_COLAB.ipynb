# %% [markdown]
# # PYTHON: 71 FUNZIONI DA CAPIRE E USARE
# ## Companion digitale - Notebook delle 71 voci
#
# Questo notebook accompagna il Vol. 2 della Collana Python & Colab.
#
# Non sostituisce le spiegazioni del libro: serve per eseguire, modificare e sperimentare il codice.

# %% [markdown]
# ### Versione di Python in uso
#
# Questa edizione del libro è stata verificata con riferimento a Python 3.14.7. Controlla qui la versione realmente utilizzata dal tuo ambiente.

# %%
import sys
print(sys.version)

# %% [markdown]
# Il libro è stato verificato con riferimento a Python 3.14.7. La versione utilizzata dall'ambiente notebook può essere diversa e può cambiare nel tempo.

# %% [markdown]
# ## Indice delle 71 voci
#
# - 01. abs()
# - 02. aiter()
# - 03. all()
# - 04. anext()
# - 05. any()
# - 06. ascii()
# - 07. bin()
# - 08. bool()
# - 09. breakpoint()
# - 10. bytearray()
# - 11. bytes()
# - 12. callable()
# - 13. chr()
# - 14. classmethod()
# - 15. compile()
# - 16. complex()
# - 17. delattr()
# - 18. dict()
# - 19. dir()
# - 20. divmod()
# - 21. enumerate()
# - 22. eval()
# - 23. exec()
# - 24. filter()
# - 25. float()
# - 26. format()
# - 27. frozenset()
# - 28. getattr()
# - 29. globals()
# - 30. hasattr()
# - 31. hash()
# - 32. help()
# - 33. hex()
# - 34. id()
# - 35. input()
# - 36. int()
# - 37. isinstance()
# - 38. issubclass()
# - 39. iter()
# - 40. len()
# - 41. list()
# - 42. locals()
# - 43. map()
# - 44. max()
# - 45. memoryview()
# - 46. min()
# - 47. next()
# - 48. object()
# - 49. oct()
# - 50. open()
# - 51. ord()
# - 52. pow()
# - 53. print()
# - 54. property()
# - 55. range()
# - 56. repr()
# - 57. reversed()
# - 58. round()
# - 59. set()
# - 60. setattr()
# - 61. slice()
# - 62. sorted()
# - 63. staticmethod()
# - 64. str()
# - 65. sum()
# - 66. super()
# - 67. tuple()
# - 68. type()
# - 69. vars()
# - 70. zip()
# - 71. __import__()
#
# Usa il pannello Sommario (Outline) per spostarti rapidamente tra le voci.

# %% [markdown]
# ## 01. abs()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 01. abs() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
budget = 1000
consuntivo = 850
scostamento = abs(consuntivo - budget)
print(scostamento)

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# 150
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia budget da 1000 a 1200 e prova a prevedere il nuovo risultato.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 02. aiter()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 02. aiter() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI
#
# Adattamento per ambiente notebook.
#
# Nel libro l'esempio usa asyncio.run(); nel notebook è già attivo un loop asincrono, quindi si usa direttamente await nella cella.

# %%
async def numeri():
    yield 10
    yield 20

it = aiter(numeri())
print(await anext(it))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# 10
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia il primo valore prodotto da 10 a 99 e prevedi che cosa verrà mostrato.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 03. all()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 03. all() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
controlli = [True, True, False]
risultato = all(controlli)
print(risultato)

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# False
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia il terzo valore da False a True e prevedi il nuovo risultato.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 04. anext()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 04. anext() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI
#
# Adattamento per ambiente notebook.
#
# Nel libro l'esempio usa asyncio.run(); nel notebook è già attivo un loop asincrono, quindi si usa direttamente await nella cella.

# %%
async def dati():
    yield "A"

it = aiter(dati())
print(await anext(it))
print(await anext(it, "fine"))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# A
# fine
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia il valore predefinito da "fine" a "nessun altro dato".

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 05. any()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 05. any() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
errori = [False, False, True, False]
print(any(errori))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# True
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia tutti i valori in False e prevedi il nuovo risultato.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 06. ascii()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 06. ascii() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
testo = "caff" + chr(232)
print(ascii(testo))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# 'caff\xe8'
# ```

# %% [markdown]
# ### MODIFICA
#
# Sostituisci chr(232) con chr(224) e osserva il nuovo codice di escape.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 07. bin()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 07. bin() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
numero = 10
risultato = bin(numero)
print(risultato)

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# 0b1010
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia il numero da 10 a 8 e prevedi la nuova forma binaria.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 08. bool()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 08. bool() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
print(bool(0))
print(bool(5))
print(bool(""))
print(bool("ciao"))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# False
# True
# False
# True
# ```

# %% [markdown]
# ### MODIFICA
#
# Aggiungi print(bool([])) e prevedi il risultato.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 09. breakpoint()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 09. breakpoint() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI
#
# ESECUZIONE MANUALE
#
# breakpoint() apre il debugger e richiede interazione. Esegui questa cella soltanto quando vuoi provare volontariamente il debugger.
#
# ```python
# prezzo = 100
# sconto = 20
# breakpoint()
# finale = prezzo - sconto
# print(finale)
# ```

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# Il programma si ferma sulla riga breakpoint() e apre il debugger. Dopo la ripresa, il risultato finale è 80.
# ```

# %% [markdown]
# ### MODIFICA
#
# Sposta breakpoint() dopo il calcolo e osserva quali variabili sono già definite.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 10. bytearray()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 10. bytearray() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
dati = bytearray([65, 66, 67])
print(dati)
dati[0] = 90
print(dati)

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# bytearray(b'ABC')
# bytearray(b'ZBC')
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia 90 in 88 e prevedi la nuova lettera.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 11. bytes()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 11. bytes() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
dati = bytes([65, 66, 67])
print(dati)

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# b'ABC'
# ```

# %% [markdown]
# ### MODIFICA
#
# Aggiungi il numero 68 alla lista e prevedi il nuovo risultato.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 12. callable()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 12. callable() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
print(callable(print))
print(callable(42))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# True
# False
# ```

# %% [markdown]
# ### MODIFICA
#
# Prova callable(len) e prevedi il risultato.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 13. chr()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 13. chr() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
print(chr(65))
print(chr(97))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# A
# a
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia 65 in 90 e prevedi la lettera ottenuta.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 14. classmethod()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 14. classmethod() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
class Persona:
    def __init__(self, nome):
        self.nome = nome

    @classmethod
    def anonima(cls):
        return cls("Sconosciuto")

p = Persona.anonima()
print(p.nome)

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# Sconosciuto
# ```

# %% [markdown]
# ### MODIFICA
#
# Aggiungi una seconda chiamata a Persona.anonima() e osserva che cosa cambia.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 15. compile()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 15. compile() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI
#
# Usa esclusivamente valori controllati. Non usare input non affidabile.

# %%
codice = compile("2 + 3", "<string>", "eval")
risultato = eval(codice)
print(risultato)

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# 5
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia l'espressione da "2 + 3" a "10 * 4" e prevedi il risultato.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 16. complex()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 16. complex() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
z = complex(2, 3)
print(z)
print(z.real)
print(z.imag)

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# (2+3j)
# 2.0
# 3.0
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia la parte immaginaria da 3 a -2 e prevedi la nuova rappresentazione.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 17. delattr()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 17. delattr() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
class Persona:
    pass

p = Persona()
p.nome = "Anna"
print(hasattr(p, "nome"))
delattr(p, "nome")
print(hasattr(p, "nome"))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# True
# False
# ```

# %% [markdown]
# ### MODIFICA
#
# Aggiungi un secondo attributo e prova a eliminarlo.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 18. dict()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 18. dict() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
persona = dict(nome="Anna", eta=30)
print(persona)
print(persona["nome"])

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# {'nome': 'Anna', 'eta': 30}
# Anna
# ```

# %% [markdown]
# ### MODIFICA
#
# Aggiungi la coppia citta="Roma" e prevedi il nuovo dizionario.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 19. dir()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 19. dir() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
nomi = dir(str)
print("upper" in nomi)
print("append" in nomi)

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# True
# False
# ```

# %% [markdown]
# ### MODIFICA
#
# Sostituisci "upper" con "lower" e prevedi il risultato.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 20. divmod()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 20. divmod() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
ore, minuti = divmod(125, 60)
print(ore)
print(minuti)

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# 2
# 5
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia 125 in 200 e prevedi ore e minuti.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 21. enumerate()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 21. enumerate() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
nomi = ["Anna", "Luca", "Sara"]
print(list(enumerate(nomi, start=1)))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# [(1, 'Anna'), (2, 'Luca'), (3, 'Sara')]
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia start da 1 a 0 e prevedi la nuova numerazione.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 22. eval()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 22. eval() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI
#
# Usa esclusivamente valori controllati. Non usare input non affidabile.

# %%
testo = "2 + 3 * 4"
risultato = eval(testo)
print(risultato)

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# 14
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia l'espressione in "10 - 4" e prevedi il risultato.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 23. exec()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 23. exec() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI
#
# Usa esclusivamente valori controllati. Non usare input non affidabile.

# %%
codice = "x = 5\nprint(x * 2)"
exec(codice)

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# 10
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia il valore assegnato a x da 5 a 7 e prevedi l'output.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 24. filter()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 24. filter() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
def positivo(n):
    return n > 0

numeri = [-2, 0, 3, 5]
risultato = list(filter(positivo, numeri))
print(risultato)

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# [3, 5]
# ```

# %% [markdown]
# ### MODIFICA
#
# Aggiungi il numero -1 alla lista e prevedi il nuovo risultato.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 25. float()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 25. float() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
prezzo_testo = "12.50"
prezzo = float(prezzo_testo)
print(prezzo)
print(prezzo * 2)

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# 12.5
# 25.0
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia il testo in "30.75" e prevedi il valore raddoppiato.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 26. format()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 26. format() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
importo = 115.0
print(format(importo, ".2f"))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# 115.00
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia la specifica da ".2f" a ".3f" e prevedi il risultato.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 27. frozenset()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 27. frozenset() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
valori = frozenset([1, 2, 2, 3])
print(len(valori))
print(2 in valori)

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# 3
# True
# ```

# %% [markdown]
# ### MODIFICA
#
# Aggiungi un altro 3 alla lista di partenza e prevedi la lunghezza.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 28. getattr()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 28. getattr() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
class Persona:
    def __init__(self):
        self.nome = "Anna"

p = Persona()
print(getattr(p, "nome"))
print(getattr(p, "eta", 0))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# Anna
# 0
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia il valore predefinito da 0 a "non indicata".

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 29. globals()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 29. globals() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI
#
# Il contenuto mostrato dipende dall'ambiente di esecuzione.

# %%
titolo = "Report"
print("titolo" in globals())
print(globals()["titolo"])

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# True
# Report
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia il nome della variabile da titolo a documento e aggiorna il controllo.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 30. hasattr()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 30. hasattr() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
class Persona:
    def __init__(self):
        self.nome = "Anna"

p = Persona()
print(hasattr(p, "nome"))
print(hasattr(p, "eta"))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# True
# False
# ```

# %% [markdown]
# ### MODIFICA
#
# Controlla l'attributo "nome" al posto di "eta" e prevedi il risultato.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 31. hash()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 31. hash() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI
#
# Il valore numerico dell'hash può dipendere dall'implementazione e dall'esecuzione.

# %%
print(hash(10))
print(hash(10) == hash(10))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# 10
# True
# ```

# %% [markdown]
# ### MODIFICA
#
# Prova hash("ciao") == hash("ciao") e prevedi il risultato.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 32. help()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 32. help() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI
#
# L'output di help() può variare leggermente in base alla versione dell'interprete.

# %%
help(len)

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# Python mostra la documentazione di len(), inclusa la sua firma e una breve descrizione.
# ```

# %% [markdown]
# ### MODIFICA
#
# Prova help(sorted) al posto di help(len).

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 33. hex()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 33. hex() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
numero = 255
print(hex(numero))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# 0xff
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia 255 in 128 e prevedi la nuova forma esadecimale.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 34. id()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 34. id() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI
#
# Il numero restituito da id() cambia da un'esecuzione all'altra: non fare affidamento sul valore preciso.

# %%
a = [1, 2]
b = a
c = [1, 2]
print(id(a) == id(b))
print(id(a) == id(c))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# True
# False
# ```

# %% [markdown]
# ### MODIFICA
#
# Aggiungi d = c e verifica id(c) == id(d).

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 35. input()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 35. input() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI
#
# Questa cella aspetta un dato digitato dalla persona.

# %%
nome = input("Come ti chiami? ")
print("Ciao", nome)

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# Se la persona scrive Anna, il programma mostra: Ciao Anna
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia il messaggio della domanda e osserva che cosa cambia a video.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 36. int()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 36. int() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
testo = "25"
numero = int(testo)
print(numero)
print(numero + 5)

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# 25
# 30
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia il testo da "25" a "40" e prevedi il risultato della somma.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 37. isinstance()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 37. isinstance() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
print(isinstance(25, int))
print(isinstance(25.0, int))
print(isinstance(25.0, (int, float)))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# True
# False
# True
# ```

# %% [markdown]
# ### MODIFICA
#
# Prova isinstance(25, float) e prevedi il risultato.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 38. issubclass()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 38. issubclass() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
class Animale:
    pass

class Cane(Animale):
    pass

print(issubclass(Cane, Animale))
print(issubclass(Animale, Cane))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# True
# False
# ```

# %% [markdown]
# ### MODIFICA
#
# Aggiungi una classe Gatto(Animale) e verifica la relazione.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 39. iter()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 39. iter() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
it = iter([10, 20, 30])
print(next(it))
print(next(it))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# 10
# 20
# ```

# %% [markdown]
# ### MODIFICA
#
# Aggiungi una terza chiamata a next e prevedi il valore ottenuto.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 40. len()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 40. len() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
testo = "Python"
numeri = [10, 20, 30]
print(len(testo))
print(len(numeri))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# 6
# 3
# ```

# %% [markdown]
# ### MODIFICA
#
# Aggiungi un elemento alla lista e prevedi il nuovo conteggio.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 41. list()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 41. list() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
lettere = list("ABC")
print(lettere)
lettere.append("D")
print(lettere)

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# ['A', 'B', 'C']
# ['A', 'B', 'C', 'D']
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia il testo da "ABC" a "PYTHON" e prevedi la nuova lista.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 42. locals()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 42. locals() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI
#
# Il contenuto mostrato dipende dall'ambiente di esecuzione.

# %%
def calcola():
    prezzo = 100
    sconto = 20
    finale = prezzo - sconto
    print(locals()["finale"])

calcola()

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# 80
# ```

# %% [markdown]
# ### MODIFICA
#
# Aggiungi una quarta variabile locale e osserva che cosa cambia.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 43. map()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 43. map() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
testi = ["10", "20", "30"]
numeri = list(map(int, testi))
print(numeri)

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# [10, 20, 30]
# ```

# %% [markdown]
# ### MODIFICA
#
# Sostituisci int con float e prevedi il nuovo risultato.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 44. max()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 44. max() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
vendite = [1200, 1800, 950, 2100]
record = max(vendite)
print(record)

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# 2100
# ```

# %% [markdown]
# ### MODIFICA
#
# Aggiungi il valore 2500 alla lista e prevedi il nuovo massimo.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 45. memoryview()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 45. memoryview() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
dati = bytearray(b"ABC")
vista = memoryview(dati)
print(vista[0])
vista[0] = 90
print(dati)

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# 65
# bytearray(b'ZBC')
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia 90 in 89 e prevedi la nuova lettera.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 46. min()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 46. min() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
prezzi = [12.5, 9.9, 14.0]
print(min(prezzi))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# 9.9
# ```

# %% [markdown]
# ### MODIFICA
#
# Aggiungi il prezzo 8.5 alla lista e prevedi il nuovo minimo.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 47. next()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 47. next() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
it = iter([10, 20])
print(next(it))
print(next(it))
print(next(it, "fine"))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# 10
# 20
# fine
# ```

# %% [markdown]
# ### MODIFICA
#
# Aggiungi un terzo elemento alla lista e prevedi i valori consegnati.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 48. object()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 48. object() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
x = object()
print(type(x) is object)
print(isinstance(x, object))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# True
# True
# ```

# %% [markdown]
# ### MODIFICA
#
# Crea un secondo oggetto e verifica se ha lo stesso tipo.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 49. oct()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 49. oct() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
print(oct(8))
print(oct(10))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# 0o10
# 0o12
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia 8 in 16 e prevedi la nuova forma ottale.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 50. open()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 50. open() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI
#
# Il file viene creato dal notebook stesso. In Google Colab i file della sessione sono temporanei.

# %%
with open("esempio.txt", "w", encoding="utf-8") as f:
    f.write("Ciao")

with open("esempio.txt", "r", encoding="utf-8") as f:
    testo = f.read()

print(testo)

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# Ciao
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia il testo scritto nel file e prevedi il nuovo output della lettura.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 51. ord()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 51. ord() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
print(ord("A"))
print(ord("a"))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# 65
# 97
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia "A" in "z" e prevedi il nuovo codice.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 52. pow()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 52. pow() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
print(pow(2, 3))
print(pow(5, 2))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# 8
# 25
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia l'esponente da 3 a 4 e prevedi il risultato.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 53. print()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 53. print() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
nome = "Anna"
eta = 30
print(nome, eta)
print("A", "B", sep="-")

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# Anna 30
# A-B
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia il separatore da "-" a " | " e prevedi il risultato.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 54. property()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 54. property() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
class Rettangolo:
    def __init__(self, base, altezza):
        self.base = base
        self.altezza = altezza

    @property
    def area(self):
        return self.base * self.altezza

r = Rettangolo(4, 3)
print(r.area)

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# 12
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia base e altezza e prevedi la nuova area.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 55. range()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 55. range() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
print(list(range(5)))
print(list(range(2, 7, 2)))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# [0, 1, 2, 3, 4]
# [2, 4, 6]
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia il passo da 2 a 3 e prevedi i valori ottenuti.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 56. repr()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 56. repr() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
testo = "ciao\n"
print(testo)
print(repr(testo))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# ciao
#
# 'ciao\n'
# ```

# %% [markdown]
# ### MODIFICA
#
# Sostituisci la stringa con "ciao\tmondo" e osserva la rappresentazione.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 57. reversed()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 57. reversed() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
valori = [1, 3, 2]
print(list(reversed(valori)))
print(valori)

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# [2, 3, 1]
# [1, 3, 2]
# ```

# %% [markdown]
# ### MODIFICA
#
# Aggiungi un quarto valore alla lista e prevedi il nuovo ordine.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 58. round()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 58. round() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
print(round(3.14159, 2))
print(round(2.5))
print(round(3.5))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# 3.14
# 2
# 4
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia 3.14159 in 2.71828 e prevedi il risultato a due decimali.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 59. set()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 59. set() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
valori = set([1, 2, 2, 3])
print(len(valori))
print(2 in valori)

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# 3
# True
# ```

# %% [markdown]
# ### MODIFICA
#
# Aggiungi un altro 3 alla lista di partenza e prevedi la lunghezza.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 60. setattr()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 60. setattr() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
class Persona:
    pass

p = Persona()
setattr(p, "nome", "Anna")
print(p.nome)
setattr(p, "nome", "Luca")
print(p.nome)

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# Anna
# Luca
# ```

# %% [markdown]
# ### MODIFICA
#
# Imposta un attributo "eta" con valore 30 e mostralo.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 61. slice()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 61. slice() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
primi_tre = slice(0, 3)
testo = "Python"
print(testo[primi_tre])
print(testo[0:3])

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# Pyt
# Pyt
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia slice(0, 3) in slice(1, 4) e prevedi il risultato.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 62. sorted()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 62. sorted() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
originale = [3, 1, 2]
ordinata = sorted(originale)
print(ordinata)
print(originale)

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# [1, 2, 3]
# [3, 1, 2]
# ```

# %% [markdown]
# ### MODIFICA
#
# Aggiungi reverse=True e prevedi il nuovo ordine.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 63. staticmethod()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 63. staticmethod() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
class Calcoli:
    @staticmethod
    def doppio(n):
        return n * 2

print(Calcoli.doppio(5))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# 10
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia il numero passato da 5 a 12 e prevedi il risultato.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 64. str()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 64. str() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
numero = 25
testo = str(numero)
print(testo)
print(type(testo))
print("Numero: " + testo)

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# 25
# <class 'str'>
# Numero: 25
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia il numero da 25 a 100 e prevedi il messaggio finale.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 65. sum()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 65. sum() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
importi = [10, 20, 5]
print(sum(importi))
print(sum(importi, 100))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# 35
# 135
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia il valore iniziale da 100 a 50 e prevedi il nuovo totale.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 66. super()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 66. super() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
class Persona:
    def __init__(self, nome):
        self.nome = nome

class Dipendente(Persona):
    def __init__(self, nome, ruolo):
        super().__init__(nome)
        self.ruolo = ruolo

d = Dipendente("Anna", "Controller")
print(d.nome)
print(d.ruolo)

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# Anna
# Controller
# ```

# %% [markdown]
# ### MODIFICA
#
# Aggiungi un terzo attributo alla sottoclasse e mostralo.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 67. tuple()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 67. tuple() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
valori = tuple([10, 20, 30])
print(valori)
print(valori[0])

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# (10, 20, 30)
# 10
# ```

# %% [markdown]
# ### MODIFICA
#
# Aggiungi un quarto valore e prevedi il nuovo contenuto.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 68. type()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 68. type() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
a = 10
b = "10"
print(type(a))
print(type(b))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# <class 'int'>
# <class 'str'>
# ```

# %% [markdown]
# ### MODIFICA
#
# Cambia b da "10" a 10.5 e prevedi il tipo mostrato.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 69. vars()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 69. vars() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
class Persona:
    def __init__(self):
        self.nome = "Anna"
        self.eta = 30

p = Persona()
print(vars(p))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# {'nome': 'Anna', 'eta': 30}
# ```

# %% [markdown]
# ### MODIFICA
#
# Aggiungi un terzo attributo nell'__init__ e prevedi il dizionario.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 70. zip()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 70. zip() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI

# %%
nomi = ["Anna", "Luca"]
voti = [8, 7]
print(list(zip(nomi, voti)))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# [('Anna', 8), ('Luca', 7)]
# ```

# %% [markdown]
# ### MODIFICA
#
# Aggiungi un terzo nome senza aggiungere il voto e prevedi il risultato.

# %%
# Scrivi qui la tua prova

# %% [markdown]
# ## 71. __import__()

# %% [markdown]
# ### LEGGI NEL LIBRO
#
# Prima di eseguire il codice, leggi la scheda 71. __import__() nel libro.

# %% [markdown]
# ### PREVEDI
#
# Prima di eseguire la cella, prova a prevedere che cosa verrà mostrato.

# %% [markdown]
# ### ESEGUI
#
# Usa esclusivamente moduli controllati. Non usare input non affidabile.

# %%
math = __import__("math")
print(math.sqrt(16))

# %% [markdown]
# ### OUTPUT ATTESO
#
# ```
# 4.0
# ```

# %% [markdown]
# ### MODIFICA
#
# Sostituisci math.sqrt(16) con math.sqrt(81) e prevedi il risultato.

# %%
# Scrivi qui la tua prova
